# %%
TASK 3) Create a clustering model to group the daily SPOT electricity price profiles in different clusters.
Identify patterns in the electricity prices data based on historical data and other features, if necessary. Are they similar?
Can you identify any patterns among the different groups detected?
